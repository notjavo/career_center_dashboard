# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
anonymous_data = pd.read_csv('streamlit_data_anonymous.csv')
app_data = pd.read_csv('applications_with_industry .csv')

# %%
apps_by_id_and_industry = app_data.groupby(['Employer Industry Name', 'Job ID']).size().reset_index(name="Applications for Job")

# %%
apps_by_id_and_industry = data.groupby(['Employer Industry Name', 'Job ID']).size().reset_index(name="Applications for Job")
# Get top 5 industries with the most unique Job IDs
top_industries = (
    apps_by_id_and_industry.groupby("Employer Industry Name")["Job ID"]
    .nunique()
    .nlargest(12)
    .index
)

# Filter dataset to include only these top industries
filtered_data = apps_by_id_and_industry[apps_by_id_and_industry["Employer Industry Name"].isin(top_industries)]

# %%
apps_by_id_and_industry = data.groupby(['Employer Industry Name', 'Job ID']).size().reset_index(name="Applications for Job")
# Get top 5 industries with the most unique Job IDs
top_industries = (
    apps_by_id_and_industry.groupby("Employer Industry Name")["Job ID"]
    .nunique()
    .nlargest(12)
    .index
)

# Filter dataset to include only these top industries
filtered_data = apps_by_id_and_industry[apps_by_id_and_industry["Employer Industry Name"].isin(top_industries)]
# Sort industries by median applications per job
industry_order = (
    filtered_data.groupby("Employer Industry Name")["Applications for Job"]
    .median()
    .sort_values()
    .index
)

# %%
anonymous_data]

# %%
data = pd.read_csv('applications_with_industry .csv')

apps_by_id_and_industry = data.groupby(['Employer Industry Name', 'Job ID']).size().reset_index(name="Applications for Job")
# Get top 5 industries with the most unique Job IDs
top_industries = (
    apps_by_id_and_industry.groupby("Employer Industry Name")["Job ID"]
    .nunique()
    .nlargest(12)
    .index
)


# Filter dataset to include only these top industries
filtered_data = apps_by_id_and_industry[apps_by_id_and_industry["Employer Industry Name"].isin(top_industries)]
# Sort industries by median applications per job
industry_order = (
    filtered_data.groupby("Employer Industry Name")["Applications for Job"]
    .median()
    .sort_values()
    .index
)

# Cap outliers at the 95th percentile to reduce skew
cap = np.percentile(filtered_data["Applications for Job"], 99)
filtered_data["Applications for Job"] = np.clip(filtered_data["Applications for Job"], None, cap)


# Compute medians
medians = filtered_data.groupby("Employer Industry Name")["Applications for Job"].median()
# Plot
plt.figure(figsize=(10, 6))
ax = sns.boxplot(data=filtered_data, x="Employer Industry Name", y="Applications for Job", order=industry_order)

# Annotate medians
for i, industry in enumerate(industry_order):
    median_val = medians[industry]
    plt.text(i, median_val, f"{median_val:.1f}", ha='center', va='bottom', fontsize=10, fontweight="bold", color="black")

plt.xticks(rotation=45)
plt.xlabel("Industry")
plt.ylabel("Applications per Job")
plt.title("Sorted Distribution of Applications per posting by industry ")

plt.show()

# %%
data = pd.read_excel('First Generation Data.xlsx')

# %%
data
# Out:
#                                            Unnamed: 0          Unnamed: 1  \
# 0                                      Student Filter  [First Generation]
# 1                           New First-Time First-Year              Totals
# 2                           New First-Time First-Year    First Generation
# 3                                                 NaN          Percentage
# 4                           New First-Time First-Year               Other
# 5                                        New Transfer              Totals
# 6                                        New Transfer    First Generation
# 7                                                 NaN          Percentage
# 8                                        New Transfer               Other
# 9                                                 NaN                 NaN
# 10  This is the number of first generation student...                 NaN
# 11                                     Student Filter  [First Generation]
# 12                                      Undergraduate              Totals
# 13                                      Undergraduate    First Generation
# 14                                      Undergraduate               Other
# 15                                      Undergraduate  Data Not Available
# 16                                           Graduate              Totals
# 17                                           Graduate    First Generation
# 18                                           Graduate               Other
# 19                                           Graduate  Data Not Available
#
#    Unnamed: 2 Class of 2020 Class of 2021 Class of 2022 Class of 2023  \
# 0   Term Desc     2016 Fall     2017 Fall     2018 Fall     2019 Fall
# 1         NaN          3683          3788          3822          3920
# 2         NaN           411           452           423           502
# 3         NaN      0.111594      0.119324      0.110675      0.128061
# 4         NaN          3272          3336          3399          3418
# 5         NaN           667           694           697           688
# 6         NaN           123           110           127           148
# 7         NaN      0.184408      0.158501      0.182209      0.215116
# 8         NaN           544           584           570           540
# 9         NaN           NaN           NaN           NaN           NaN
# 10        NaN           NaN           NaN           NaN           NaN
# 11  Term Desc     2016 Fall     2017 Fall     2018 Fall     2019 Fall
# 12        NaN         16331         16655         16777         17011
# 13        NaN          1640          1753          1830          2051
# 14        NaN         14574         14837         14905         14925
# 15        NaN           117            65            42            35
# 16        NaN          7567          7705          7862          8007
# 17        NaN             -             -             -             -
# 18        NaN             -             -             -             -
# 19        NaN          7567          7705          7862          8007
#
#    Class of 2024 Class of 2025 Class of 2026 Class of 2027 Class of 2028
# 0      2020 Fall     2021 Fall     2022 Fall     2023 Fall     2024 Fall
# 1           3785          3889          4020          3966          3961
# 2            515           465           628           689           746
# 3       0.136063      0.119568      0.156219      0.173727      0.188336
# 4           3270          3424          3392          3277          3215
# 5            768           759           743           779           851
# 6            194           181           151           200           223
# 7       0.252604      0.238472       0.20323      0.256739      0.262045
# 8            574           578           592           579           628
# 9            NaN           NaN           NaN           NaN           NaN
# 10           NaN           NaN           NaN           NaN           NaN
# 11     2020 Fall     2021 Fall     2022 Fall     2023 Fall     2024 Fall
# 12         17314         17299         17496         17618         17901
# 13          2288          2328          2453          2749          3030
# 14         15001         14960         15034         14860         14865
# 15            25            11  less than 10  less than 10  less than 10
# 16          8328          8727          8653          8326          8569
# 17           486           921          1131          1269          1441
# 18          3106          5313          6156          6334          6783
# 19          4736          2493          1366           723           345

# %%
anonymous_data
# Out:
#        num_fairs  Internship Applications  Job Applications  \
# 0            1.0                      NaN               NaN
# 1            1.0                      NaN               NaN
# 2            1.0                      NaN               NaN
# 3            1.0                      NaN               NaN
# 4            1.0                      NaN               NaN
# ...          ...                      ...               ...
# 36243        1.0                      NaN               NaN
# 36244        1.0                      5.0               0.0
# 36245        1.0                      NaN               NaN
# 36246        1.0                      NaN               NaN
# 36247        5.0                     83.0              26.0
#
#        Fellowship_application  Graduate School  Cooperative Education  \
# 0                         NaN              NaN                    NaN
# 1                         NaN              NaN                    NaN
# 2                         NaN              NaN                    NaN
# 3                         NaN              NaN                    NaN
# 4                         NaN              NaN                    NaN
# ...                       ...              ...                    ...
# 36243                     NaN              NaN                    NaN
# 36244                     0.0              0.0                    0.0
# 36245                     NaN              NaN                    NaN
# 36246                     NaN              NaN                    NaN
# 36247                     0.0              0.0                    0.0
#
#        Experiential Learning  On Campus Student Employment  Volunteer  \
# 0                        NaN                           NaN        NaN
# 1                        NaN                           NaN        NaN
# 2                        NaN                           NaN        NaN
# 3                        NaN                           NaN        NaN
# 4                        NaN                           NaN        NaN
# ...                      ...                           ...        ...
# 36243                    NaN                           NaN        NaN
# 36244                    0.0                           0.0        0.0
# 36245                    NaN                           NaN        NaN
# 36246                    NaN                           NaN        NaN
# 36247                    0.0                           9.0        0.0
#
#       First Gen                           College_fds_2024  \
# 0           NaN                                        NaN
# 1           NaN                                        NaN
# 2           NaN                                        NaN
# 3           NaN                                        NaN
# 4           NaN                                        NaN
# ...         ...                                        ...
# 36243     False  School of Education and Human Development
# 36244       NaN                                        NaN
# 36245       NaN                                        NaN
# 36246     False  School of Education and Human Development
# 36247     False                                        NaN
#
#       Number of Internships  Career Readiness  Alignment  Q10.4_fds_2024  \
# 0                       NaN               NaN        NaN             NaN
# 1                       NaN               NaN        NaN             NaN
# 2                       NaN               NaN        NaN             NaN
# 3                       NaN               NaN        NaN             NaN
# 4                       NaN               NaN        NaN             NaN
# ...                     ...               ...        ...             ...
# 36243                   NaN               NaN        NaN             NaN
# 36244                   NaN               NaN        NaN             NaN
# 36245                   NaN               NaN        NaN             NaN
# 36246                     0               7.0        9.0             8.0
# 36247                   NaN               NaN        NaN             NaN
#
#        Q10.5_fds_2024 time of IPP
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# ...               ...         ...
# 36243             NaN         NaN
# 36244             NaN         NaN
# 36245             NaN         NaN
# 36246            10.0         NaN
# 36247             NaN         NaN
#
# [36248 rows x 17 columns]

# %%
alignment = anonymous_data['Alignment'].value_counts(normalize=True).reset_index(name='Percent')
alignment['Percent'] = alignment['Percent'] * 100
alignment
# Out:
#     Alignment    Percent
# 0        10.0  29.795158
# 1         8.0  20.716946
# 2         9.0  14.385475
# 3         7.0  13.361266
# 4         6.0   7.867784
# 5         5.0   6.052142
# 6         3.0   2.513966
# 7         4.0   2.094972
# 8         2.0   1.722533
# 9         0.0   1.070764
# 10        1.0   0.418994
